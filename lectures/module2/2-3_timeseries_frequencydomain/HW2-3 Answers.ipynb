# %% [markdown]
# ## Important: Run this code cell each time you start a new session!

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install scipy
# !pip install os
# !pip install wfdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import os
import wfdb
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.23.5)
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# Collecting wfdb
#   Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb) (3.7.1)
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.23.5)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.5.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.31.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2023.11.17)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Installing collected packages: wfdb
# Successfully installed wfdb-4.1.2

# %%
# !wget -nc https://archive.physionet.org/users/shared/challenge-2019/training_setA.zip
# !unzip -n training_setA.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: training/p015337.psv
#   inflating: training/p015338.psv
#   inflating: training/p015339.psv
#   inflating: training/p015340.psv
#   inflating: training/p015341.psv
#   inflating: training/p015342.psv
#   inflating: training/p015343.psv
#   inflating: training/p015344.psv
#   inflating: training/p015345.psv
#   inflating: training/p015346.psv
#   inflating: training/p015347.psv
#   inflating: training/p015348.psv
#   inflating: training/p015349.psv
#   inflating: training/p015350.psv
#   inflating: training/p015351.psv
#   inflating: training/p015352.psv
#   inflating: training/p015353.psv
#   inflating: training/p015354.psv
#   inflating: training/p015355.psv
#   inflating: training/p015356.psv
#   inflating: training/p015357.psv
#   inflating: training/p015358.psv
#   inflating: training/p015359.psv
#   inflating: training/p015360.psv
#   inflating: training/p015361.psv
#   inflating: training/p015362.psv
#   inflating: training/p015363.psv
#   inflating: training/p015364.psv
#   inflating: training/p015365.psv
#   inflating: training/p015366.psv
#   inflating: training/p015367.psv
#   inflating: training/p015368.psv
#   inflating: training/p015369.psv
#   inflating: training/p015370.psv
#   inflating: training/p015371.psv
#   inflating: training/p015372.psv
#   inflating: training/p015373.psv
#   inflating: training/p015374.psv
#   inflating: training/p015375.psv
#   inflating: training/p015376.psv
#   inflating: training/p015377.psv
#   inflating: training/p015378.psv
#   inflating: training/p015379.psv
#   inflating: training/p015380.psv
#   inflating: training/p015381.psv
#   inflating: training/p015382.psv
#   inflating: training/p015383.psv
#   inflating: training/p015384.psv
#   inflating: training/p015385.psv
#   inflating: training/p015386.psv
#   inflating: training/p015387.psv
#   inflating: training/p015388.psv
#   inflating: training/p015389.psv
#   inflating: training/p015390.psv
#   inflating: training/p015391.psv
#   inflating: training/p015392.psv
#   inflating: training/p015393.psv
#   inflating: training/p015394.psv
#   inflating: training/p015395.psv
#   inflating: training/p015396.psv
#   inflating: training/p015397.psv
#   inflating: training/p015398.psv
#   inflating: training/p015399.psv
#   inflating: training/p015400.psv
#   inflating: training/p015401.psv
#   inflating: training/p015402.psv
#   inflating: training/p015403.psv
#   inflating: training/p015404.psv
#   inflating: training/p015405.psv
#   inflating: training/p015406.psv
#   inflating: training/p015407.psv
#   inflating: training/p015408.psv
#   inflating: training/p015409.psv
#   inflating: training/p015410.psv
#   inflating: training/p015411.psv
#   inflating: training/p015412.psv
#   inflating: training/p015413.psv
#   inflating: training/p015414.psv
#   inflating: training/p015415.psv
#   inflating: training/p015416.psv
#   inflating: training/p015417.psv
#   inflating: training/p015418.psv
#   inflating: training/p015419.psv
#   inflating: training/p015420.psv
#   inflating: training/p015421.psv
#   inflating: training/p015422.psv
#   inflating: training/p015423.psv
#   inflating: training/p015424.psv
#   inflating: training/p015425.psv
#   inflating: training/p015426.psv
#   inflating: training/p015427.psv
#   inflating: training/p015428.psv
#   inflating: training/p015429.psv
#   inflating: training/p015430.psv
#   inflating: training/p015431.psv
#   inflating: training/p015432.psv
#   inflating: training/p015433.psv
#   inflating: training/p015434.psv
#   inflating: training/p015435.psv
#   inflating: training/p015436.psv
#   inflating: training/p015437.psv
#   inflating: training/p015438.psv
#   inflating: training/p015439.psv
#   inflating: training/p015440.psv
#   inflating: training/p015441.psv
#   inflating: training/p015442.psv
#   inflating: training/p015443.psv
#   inflating: training/p015444.psv
#   inflating: training/p015445.psv
#   inflating: training/p015446.psv
#   inflating: training/p015447.psv
#   inflating: training/p015448.psv
#   inflating: training/p015449.psv
#   inflating: training/p015450.psv
#   inflating: training/p015451.psv
#   inflating: training/p015452.psv
#   inflating: training/p015453.psv
#   inflating: training/p015454.psv
#   inflating: training/p015455.psv
#   inflating: training/p015456.psv
#   inflating: training/p015457.psv
#   inflating: training/p015458.psv
#   inflating: training/p015459.psv
#   inflating: training/p015460.psv
#   inflating: training/p015461.psv
#   inflating: training/p015462.psv
#   inflating: training/p015463.psv
#   inflating: training/p015464.psv
#   inflating: training/p015465.psv
#   inflating: training/p015466.psv
#   inflating: training/p015467.psv
#   inflating: training/p015468.psv
#   inflating: training/p015469.psv
#   inflating: training/p015470.psv
#   inflating: training/p015471.psv
#   inflating: training/p015472.psv
#   inflating: training/p015473.psv
#   inflating: training/p015474.psv
#   inflating: training/p015475.psv
#   inflating: training/p015476.psv
#   inflating: training/p015477.psv
#   inflating: training/p015478.psv
#   inflating: training/p015479.psv
#   inflating: training/p015480.psv
#   inflating: training/p015481.psv
#   inflating: training/p015482.psv
#   inflating: training/p015483.psv
#   inflating: training/p015484.psv
#   inflating: training/p015485.psv
#   inflating: training/p015486.psv
#   inflating: training/p015487.psv
#   inflating: training/p015488.psv
#   inflating: training/p015489.psv
#   inflating: training/p015490.psv
#   inflating: training/p015491.psv
#   inflating: training/p015492.psv
#   inflating: training/p015493.psv
#   inflating: training/p015494.psv
#   inflating: training/p015495.psv
#   inflating: training/p015496.psv
#   inflating: training/p015497.psv
#   inflating: training/p015498.psv
#   inflating: training/p015499.psv
#   inflating: training/p015500.psv
#   inflating: training/p015501.psv
#   inflating: training/p015502.psv
#   inflating: training/p015503.psv
#   inflating: training/p015504.psv
#   inflating: training/p015505.psv
#   inflating: training/p015506.psv
#   inflating: training/p015507.psv
#   inflating: training/p015508.psv
#   inflating: training/p015509.psv
#   inflating: training/p015510.psv
#   inflating: training/p015511.psv
#   inflating: training/p015512.psv
#   inflating: training/p015513.psv
#   inflating: training/p015514.psv
#   inflating: training/p015515.psv
#   inflating: training/p015516.psv
#   inflating: training/p015517.psv
#   inflating: training/p015518.psv
#   inflating: training/p015519.psv
#   inflating: training/p015520.psv
#   inflating: training/p015521.psv
#   inflating: training/p015522.psv
#   inflating: training/p015523.psv
#   inflating: training/p015524.psv
#   inflating: training/p015525.psv
#   inflating: training/p015526.psv
#   inflating: training/p015527.psv
#   inflating: training/p015528.psv
#   inflating: training/p015529.psv
#   inflating: training/p015530.psv
#   inflating: training/p015531.psv
#   inflating: training/p015532.psv
#   inflating: training/p015533.psv
#   inflating: training/p015534.psv
#   inflating: training/p015535.psv
#   inflating: training/p015536.psv
#   inflating: training/p015537.psv
#   inflating: training/p015538.psv
#   inflating: training/p015539.psv
#   inflating: training/p015540.psv
#   inflating: training/p015541.psv
#   inflating: training/p015542.psv
#   inflating: training/p015543.psv
#   inflating: training/p015544.psv
#   inflating: training/p015545.psv
#   inflating: training/p015546.psv
#   inflating: training/p015547.psv
#   inflating: training/p015548.psv
#   inflating: training/p015549.psv
#   inflating: training/p015550.psv
#   inflating: training/p015551.psv
#   inflating: training/p015552.psv
#   inflating: training/p015553.psv
#   inflating: training/p015554.psv
#   inflating: training/p015555.psv
#   inflating: training/p015556.psv
#   inflating: training/p015557.psv
#   inflating: training/p015558.psv
#   inflating: training/p015559.psv
#   inflating: training/p015560.psv
#   inflating: training/p015561.psv
#   inflating: training/p015562.psv
#   inflating: training/p015563.psv
#   inflating: training/p015564.psv
#   inflating: training/p015565.psv
#   inflating: training/p015566.psv
#   inflating: training/p015567.psv
#   inflating: training/p015568.psv
#   inflating: training/p015569.psv
#   inflating: training/p015570.psv
#   inflating: training/p015571.psv
#   inflating: training/p015572.psv
#   inflating: training/p015573.psv
#   inflating: training/p015574.psv
#   inflating: training/p015575.psv
#   inflating: training/p015576.psv
#   inflating: training/p015577.psv
#   inflating: training/p015578.psv
#   inflating: training/p015579.psv
#   inflating: training/p015580.psv
#   inflating: training/p015581.psv
#   inflating: training/p015582.psv
#   inflating: training/p015583.psv
#   inflating: training/p015584.psv
#   inflating: training/p015585.psv
#   inflating: training/p015586.psv
#   inflating: training/p015587.psv
#   inflating: training/p015588.psv
#   inflating: training/p015589.psv
#   inflating: training/p015590.psv
#   inflating: training/p015591.psv
#   inflating: training/p015592.psv
#   inflating: training/p015593.psv
#   inflating: training/p015594.psv
#   inflating: training/p015595.psv
#   inflating: training/p015596.psv
#   inflating: training/p015597.psv
#   inflating: training/p015598.psv
#   inflating: training/p015599.psv
#   inflating: training/p015600.psv
#   inflating: training/p015601.psv
#   inflating: training/p015602.psv
#   inflating: training/p015603.psv
#   inflating: training/p015604.psv
#   inflating: training/p015605.psv
#   inflating: training/p015606.psv
#   inflating: training/p015607.psv
#   inflating: training/p015608.psv
#   inflating: training/p015609.psv
#   inflating: training/p015610.psv
#   inflating: training/p015611.psv
#   inflating: training/p015612.psv
#   inflating: training/p015613.psv
#   inflating: training/p015614.psv
#   inflating: training/p015615.psv
#   inflating: training/p015616.psv
#   inflating: training/p015617.psv
#   inflating: training/p015618.psv
#   inflating: training/p015619.psv
#   inflating: training/p015620.psv
#   inflating: training/p015621.psv
#   inflating: training/p015622.psv
#   inflating: training/p015623.psv
#   inflating: training/p015624.psv
#   inflating: training/p015625.psv
#   inflating: training/p015626.psv
#   inflating: training/p015627.psv
#   inflating: training/p015628.psv
#   inflating: training/p015629.psv
#   inflating: training/p015630.psv
#   inflating: training/p015631.psv
#   inflating: training/p015632.psv
#   inflating: training/p015633.psv
#   inflating: training/p015634.psv
#   inflating: training/p015635.psv
#   inflating: training/p015636.psv
#   inflating: training/p015637.psv
#   inflating: training/p015638.psv
#   inflating: training/p015639.psv
#   inflating: training/p015640.psv
#   inflating: training/p015641.psv
#   inflating: training/p015642.psv
#   inflating: training/p015643.psv
#   inflating: training/p015644.psv
#   inflating: training/p015645.psv
#   inflating: training/p015646.psv
#   inflating: training/p015647.psv
#   inflating: training/p015648.psv
#   inflating: training/p015649.psv
#   inflating: training/p015650.psv
#   inflating: training/p015651.psv
#   inflating: training/p015652.psv
#   inflating: training/p015653.psv
#   inflating: training/p015654.psv
#   inflating: training/p015655.psv
#   inflating: training/p015656.psv
#   inflating: training/p015657.psv
#   inflating: training/p015658.psv
#   inflating: training/p015659.psv
#   inflating: training/p015660.psv
#   inflating: training/p015661.psv
#   inflating: training/p015662.psv
#   inflating: training/p015663.psv
#   inflating: training/p015664.psv
#   inflating: training/p015665.psv
#   inflating: training/p015666.psv
#   inflating: training/p015667.psv
#   inflating: training/p015668.psv
#   inflating: training/p015669.psv
#   inflating: training/p015670.psv
#   inflating: training/p015671.psv
#   inflating: training/p015672.psv
#   inflating: training/p015673.psv
#   inflating: training/p015674.psv
#   inflating: training/p015675.psv
#   inflating: training/p015676.psv
#   inflating: training/p015677.psv
#   inflating: training/p015678.psv
#   inflating: training/p015679.psv
#   inflating: training/p015680.psv
#   inflating: training/p015681.psv
#   inflating: training/p015682.psv
#   inflating: training/p015683.psv
#   inflating: training/p015684.psv
#   inflating: training/p015685.psv
#   inflating: training/p015686.psv
#   inflating: training/p015687.psv
#   inflating: training/p015688.psv
#   inflating: training/p015689.psv
#   inflating: training/p015690.psv
#   inflating: training/p015691.psv
#   inflating: training/p015692.psv
#   inflating: training/p015693.psv
#   inflating: training/p015694.psv
#   inflating: training/p015695.psv
#   inflating: training/p015696.psv
#   inflating: training/p015697.psv
#   inflating: training/p015698.psv
#   inflating: training/p015699.psv
#   inflating: training/p015700.psv
#   inflating: training/p015701.psv
#   inflating: training/p015702.psv
#   inflating: training/p015703.psv
#   inflating: training/p015704.psv
#   inflating: training/p015705.psv
#   inflating: training/p015706.psv
#   inflating: training/p015707.psv
#   inflating: training/p015708.psv
#   inflating: training/p015709.psv
#   inflating: training/p015710.psv
#   inflating: training/p015711.psv
#   inflating: training/p015712.psv
#   inflating: training/p015713.psv
#   inflating: training/p015714.psv
#   inflating: training/p015715.psv
#   inflating: training/p015716.psv
#   inflating: training/p015717.psv
#   inflating: training/p015718.psv
#   inflating: training/p015719.psv
#   inflating: training/p015720.psv
#   inflating: training/p015721.psv
#   inflating: training/p015722.psv
#   inflating: training/p015723.psv
#   inflating: training/p015724.psv
#   inflating: training/p015725.psv
#   inflating: training/p015726.psv
#   inflating: training/p015727.psv
#   inflating: training/p015728.psv
#   inflating: training/p015729.psv
#   inflating: training/p015730.psv
#   inflating: training/p015731.psv
#   inflating: training/p015732.psv
#   inflating: training/p015733.psv
#   inflating: training/p015734.psv
#   inflating: training/p015735.psv
#   inflating: training/p015736.psv
#   inflating: training/p015737.psv
#   inflating: training/p015738.psv
#   inflating: training/p015739.psv
#   inflating: training/p015740.psv
#   inflating: training/p015741.psv
#   inflating: training/p015742.psv
#   inflating: training/p015743.psv
#   inflating: training/p015744.psv
#   inflating: training/p015745.psv
#   inflating: training/p015746.psv
#   inflating: training/p015747.psv
#   inflating: training/p015748.psv
#   inflating: training/p015749.psv
#   inflating: training/p015750.psv
#   inflating: training/p015751.psv
#   inflating: training/p015752.psv
#   inflating: training/p015753.psv
#   inflating: training/p015754.psv
#   inflating: training/p015755.psv
#   inflating: training/p015756.psv
#   inflating: training/p015757.psv
#   inflating: training/p015758.psv
#   inflating: training/p015759.psv
#   inflating: training/p015760.psv
#   inflating: training/p015761.psv
#   inflating: training/p015762.psv
#   inflating: training/p015763.psv
#   inflating: training/p015764.psv
#   inflating: training/p015765.psv
#   inflating: training/p015766.psv
#   inflating: training/p015767.psv
#   inflating: training/p015768.psv
#   inflating: training/p015769.psv
#   inflating: training/p015770.psv
#   inflating: training/p015771.psv
#   inflating: training/p015772.psv
#   inflating: training/p015773.psv
#   inflating: training/p015774.psv
#   inflating: training/p015775.psv
#   inflating: training/p015776.psv
#   inflating: training/p015777.psv
#   inflating: training/p015778.psv
#   inflating: training/p015779.psv
#   inflating: training/p015780.psv
#   inflating: training/p015781.psv
#   inflating: training/p015782.psv
#   inflating: training/p015783.psv
#   inflating: training/p015784.psv
#   inflating: training/p015785.psv
#   inflating: training/p015786.psv
#   inflating: training/p015787.psv
#   inflating: training/p015788.psv
#   inflating: training/p015789.psv
#   inflating: training/p015790.psv
#   inflating: training/p015791.psv
#   inflating: training/p015792.psv
#   inflating: training/p015793.psv
#   inflating: training/p015794.psv
#   inflating: training/p015795.psv
#   inflating: training/p015796.psv
#   inflating: training/p015797.psv
#   inflating: training/p015798.psv
#   inflating: training/p015799.psv
#   inflating: training/p015800.psv
#   inflating: training/p015801.psv
#   inflating: training/p015802.psv
#   inflating: training/p015803.psv
#   inflating: training/p015804.psv
#   inflating: training/p015805.psv
#   inflating: training/p015806.psv
#   inflating: training/p015807.psv
#   inflating: training/p015808.psv
#   inflating: training/p015809.psv
#   inflating: training/p015810.psv
#   inflating: training/p015811.psv
#   inflating: training/p015812.psv
#   inflating: training/p015813.psv
#   inflating: training/p015814.psv
#   inflating: training/p015815.psv
#   inflating: training/p015816.psv
#   inflating: training/p015817.psv
#   inflating: training/p015818.psv
#   inflating: training/p015819.psv
#   inflating: training/p015820.psv
#   inflating: training/p015821.psv
#   inflating: training/p015822.psv
#   inflating: training/p015823.psv
#   inflating: training/p015824.psv
#   inflating: training/p015825.psv
#   inflating: training/p015826.psv
#   inflating: training/p015827.psv
#   inflating: training/p015828.psv
#   inflating: training/p015829.psv
#   inflating: training/p015830.psv
#   inflating: training/p015831.psv
#   inflating: training/p015832.psv
#   inflating: training/p015833.psv
#   inflating: training/p015834.psv
#   inflating: training/p015835.psv
#   inflating: training/p015836.psv
#   inflating: training/p015837.psv
#   inflating: training/p015838.psv
#   inflating: training/p015839.psv
#   inflating: training/p015840.psv
#   inflating: training/p015841.psv
#   inflating: training/p015842.psv
#   inflating: training/p015843.psv
#   inflating: training/p015844.psv
#   inflating: training/p015845.psv
#   inflating: training/p015846.psv
#   inflating: training/p015847.psv
#   inflating: training/p015848.psv
#   inflating: training/p015849.psv
#   inflating: training/p015850.psv
#   inflating: training/p015851.psv
#   inflating: training/p015852.psv
#   inflating: training/p015853.psv
#   inflating: training/p015854.psv
#   inflating: training/p015855.psv
#   inflating: training/p015856.psv
#   inflating: training/p015857.psv
#   inflating: training/p015858.psv
#   inflating: training/p015859.psv
#   inflating: training/p015860.psv
#   inflating: training/p015861.psv
#   inflating: training/p015862.psv
#   inflating: training/p015863.psv
#   inflating: training/p015864.psv
#   inflating: training/p015865.psv
#   inflating: training/p015866.psv
#   inflating: training/p015867.psv
#   inflating: training/p015868.psv
#   inflating: training/p015869.psv
#   inflating: training/p015870.psv
#   inflating: training/p015871.psv
#   inflating: training/p015872.psv
#   inflating: training/p015873.psv
#   inflating: training/p015874.psv
#   inflating: training/p015875.psv
#   inflating: training/p015876.psv
#   inflating: training/p015877.psv
#   inflating: training/p015878.psv
#   inflating: training/p015879.psv
#   inflating: training/p015880.psv
#   inflating: training/p015881.psv
#   inflating: training/p015882.psv
#   inflating: training/p015883.psv
#   inflating: training/p015884.psv
#   inflating: training/p015885.psv
#   inflating: training/p015886.psv
#   inflating: training/p015887.psv
#   inflating: training/p015888.psv
#   inflating: training/p015889.psv
#   inflating: training/p015890.psv
#   inflating: training/p015891.psv
#   inflating: training/p015892.psv
#   inflating: training/p015893.psv
#   inflating: training/p015894.psv
#   inflating: training/p015895.psv
#   inflating: training/p015896.psv
#   inflating: training/p015897.psv
#   inflating: training/p015898.psv
#   inflating: training/p015899.psv
#   inflating: training/p015900.psv
#   inflating: training/p015901.psv
#   inflating: training/p015902.psv
#   inflating: training/p015903.psv
#   inflating: training/p015904.psv
#   inflating: training/p015905.psv
#   inflating: training/p015906.psv
#   inflating: training/p015907.psv
#   inflating: training/p015908.psv
#   inflating: training/p015909.psv
#   inflating: training/p015910.psv
#   inflating: training/p015911.psv
#   inflating: training/p015912.psv
#   inflating: training/p015913.psv
#   inflating: training/p015914.psv
#   inflating: training/p015915.psv
#   inflating: training/p015916.psv
#   inflating: training/p015917.psv
#   inflating: training/p015918.psv
#   inflating: training/p015919.psv
#   inflating: training/p015920.psv
#   inflating: training/p015921.psv
#   inflating: training/p015922.psv
#   inflating: training/p015923.psv
#   inflating: training/p015924.psv
#   inflating: training/p015925.psv
#   inflating: training/p015926.psv
#   inflating: training/p015927.psv
#   inflating: training/p015928.psv
#   inflating: training/p015929.psv
#   inflating: training/p015930.psv
#   inflating: training/p015931.psv
#   inflating: training/p015932.psv
#   inflating: training/p015933.psv
#   inflating: training/p015934.psv
#   inflating: training/p015935.psv
#   inflating: training/p015936.psv
#   inflating: training/p015937.psv
#   inflating: training/p015938.psv
#   inflating: training/p015939.psv
#   inflating: training/p015940.psv
#   inflating: training/p015941.psv
#   inflating: training/p015942.psv
#   inflating: training/p015943.psv
#   inflating: training/p015944.psv
#   inflating: training/p015945.psv
#   inflating: training/p015946.psv
#   inflating: training/p015947.psv
#   inflating: training/p015948.psv
#   inflating: training/p015949.psv
#   inflating: training/p015950.psv
#   inflating: training/p015951.psv
#   inflating: training/p015952.psv
#   inflating: training/p015953.psv
#   inflating: training/p015954.psv
#   inflating: training/p015955.psv
#   inflating: training/p015956.psv
#   inflating: training/p015957.psv
#   inflating: training/p015958.psv
#   inflating: training/p015959.psv
#   inflating: training/p015960.psv
#   inflating: training/p015961.psv
#   inflating: training/p015962.psv
#   inflating: training/p015963.psv
#   inflating: training/p015964.psv
#   inflating: training/p015965.psv
#   inflating: training/p015966.psv
#   inflating: training/p015967.psv
#   inflating: training/p015968.psv
#   inflating: training/p015969.psv
#   inflating: training/p015970.psv
#   inflating: training/p015971.psv
#   inflating: training/p015972.psv
#   inflating: training/p015973.psv
#   inflating: training/p015974.psv
#   inflating: training/p015975.psv
#   inflating: training/p015976.psv
#   inflating: training/p015977.psv
#   inflating: training/p015978.psv
#   inflating: training/p015979.psv
#   inflating: training/p015980.psv
#   inflating: training/p015981.psv
#   inflating: training/p015982.psv
#   inflating: training/p015983.psv
#   inflating: training/p015984.psv
#   inflating: training/p015985.psv
#   inflating: training/p015986.psv
#   inflating: training/p015987.psv
#   inflating: training/p015988.psv
#   inflating: training/p015989.psv
#   inflating: training/p015990.psv
#   inflating: training/p015991.psv
#   inflating: training/p015992.psv
#   inflating: training/p015993.psv
#   inflating: training/p015994.psv
#   inflating: training/p015995.psv
#   inflating: training/p015996.psv
#   inflating: training/p015997.psv
#   inflating: training/p015998.psv
#   inflating: training/p015999.psv
#   inflating: training/p016000.psv
#   inflating: training/p016001.psv
#   inflating: training/p016002.psv
#   inflating: training/p016003.psv
#   inflating: training/p016004.psv
#   inflating: training/p016005.psv
#   inflating: training/p016006.psv
#   inflating: training/p016007.psv
#   inflating: training/p016008.psv
#   inflating: training/p016009.psv
#   inflating: training/p016010.psv
#   inflating: training/p016011.psv
#   inflating: training/p016012.psv
#   inflating: training/p016013.psv
#   inflating: training/p016014.psv
#   inflating: training/p016015.psv
#   inflating: training/p016016.psv
#   inflating: training/p016017.psv
#   inflating: training/p016018.psv
#   inflating: training/p016019.psv
#   inflating: training/p016020.psv
#   inflating: training/p016021.psv
#   inflating: training/p016022.psv
#   inflating: training/p016023.psv
#   inflating: training/p016024.psv
#   inflating: training/p016025.psv
#   inflating: training/p016026.psv
#   inflating: training/p016027.psv
#   inflating: training/p016028.psv
#   inflating: training/p016029.psv
#   inflating: training/p016030.psv
#   inflating: training/p016031.psv
#   inflating: training/p016032.psv
#   inflating: training/p016033.psv
#   inflating: training/p016034.psv
#   inflating: training/p016035.psv
#   inflating: training/p016036.psv
#   inflating: training/p016037.psv
#   inflating: training/p016038.psv
#   inflating: training/p016039.psv
#   inflating: training/p016040.psv
#   inflating: training/p016041.psv
#   inflating: training/p016042.psv
#   inflating: training/p016043.psv
#   inflating: training/p016044.psv
#   inflating: training/p016045.psv
#   inflating: training/p016046.psv
#   inflating: training/p016047.psv
#   inflating: training/p016048.psv
#   inflating: training/p016049.psv
#   inflating: training/p016050.psv
#   inflating: training/p016051.psv
#   inflating: training/p016052.psv
#   inflating: training/p016053.psv
#   inflating: training/p016054.psv
#   inflating: training/p016055.psv
#   inflating: training/p016056.psv
#   inflating: training/p016057.psv
#   inflating: training/p016058.psv
#   inflating: training/p016059.psv
#   inflating: training/p016060.psv
#   inflating: training/p016061.psv
#   inflating: training/p016062.psv
#   inflating: training/p016063.psv
#   inflating: training/p016064.psv
#   inflating: training/p016065.psv
#   inflating: training/p016066.psv
#   inflating: training/p016067.psv
#   inflating: training/p016068.psv
#   inflating: training/p016069.psv
#   inflating: training/p016070.psv
#   inflating: training/p016071.psv
#   inflating: training/p016072.psv
#   inflating: training/p016073.psv
#   inflating: training/p016074.psv
#   inflating: training/p016075.psv
#   inflating: training/p016076.psv
#   inflating: training/p016077.psv
#   inflating: training/p016078.psv
#   inflating: training/p016079.psv
#   inflating: training/p016080.psv
#   inflating: training/p016081.psv
#   inflating: training/p016082.psv
#   inflating: training/p016083.psv
#   inflating: training/p016084.psv
#   inflating: training/p016085.psv
#   inflating: training/p016086.psv
#   inflating: training/p016087.psv
#   inflating: training/p016088.psv
#   inflating: training/p016089.psv
#   inflating: training/p016090.psv
#   inflating: training/p016091.psv
#   inflating: training/p016092.psv
#   inflating: training/p016093.psv
#   inflating: training/p016094.psv
#   inflating: training/p016095.psv
#   inflating: training/p016096.psv
#   inflating: training/p016097.psv
#   inflating: training/p016098.psv
#   inflating: training/p016099.psv
#   inflating: training/p016100.psv
#   inflating: training/p016101.psv
#   inflating: training/p016102.psv
#   inflating: training/p016103.psv
#   inflating: training/p016104.psv
#   inflating: training/p016105.psv
#   inflating: training/p016106.psv
#   inflating: training/p016107.psv
#   inflating: training/p016108.psv
#   inflating: training/p016109.psv
#   inflating: training/p016110.psv
#   inflating: training/p016111.psv
#   inflating: training/p016112.psv
#   inflating: training/p016113.psv
#   inflating: training/p016114.psv
#   inflating: training/p016115.psv
#   inflating: training/p016116.psv
#   inflating: training/p016117.psv
#   inflating: training/p016118.psv
#   inflating: training/p016119.psv
#   inflating: training/p016120.psv
#   inflating: training/p016121.psv
#   inflating: training/p016122.psv
#   inflating: training/p016123.psv
#   inflating: training/p016124.psv
#   inflating: training/p016125.psv
#   inflating: training/p016126.psv
#   inflating: training/p016127.psv
#   inflating: training/p016128.psv
#   inflating: training/p016129.psv
#   inflating: training/p016130.psv
#   inflating: training/p016131.psv
#   inflating: training/p016132.psv
#   inflating: training/p016133.psv
#   inflating: training/p016134.psv
#   inflating: training/p016135.psv
#   inflating: training/p016136.psv
#   inflating: training/p016137.psv
#   inflating: training/p016138.psv
#   inflating: training/p016139.psv
#   inflating: training/p016140.psv
#   inflating: training/p016141.psv
#   inflating: training/p016142.psv
#   inflating: training/p016143.psv
#   inflating: training/p016144.psv
#   inflating: training/p016145.psv
#   inflating: training/p016146.psv
#   inflating: training/p016147.psv
#   inflating: training/p016148.psv
#   inflating: training/p016149.psv
#   inflating: training/p016150.psv
#   inflating: training/p016151.psv
#   inflating: training/p016152.psv
#   inflating: training/p016153.psv
#   inflating: training/p016154.psv
#   inflating: training/p016155.psv
#   inflating: training/p016156.psv
#   inflating: training/p016157.psv
#   inflating: training/p016158.psv
#   inflating: training/p016159.psv
#   inflating: training/p016160.psv
#   inflating: training/p016161.psv
#   inflating: training/p016162.psv
#   inflating: training/p016163.psv
#   inflating: training/p016164.psv
#   inflating: training/p016165.psv
#   inflating: training/p016166.psv
#   inflating: training/p016167.psv
#   inflating: training/p016168.psv
#   inflating: training/p016169.psv
#   inflating: training/p016170.psv
#   inflating: training/p016171.psv
#   inflating: training/p016172.psv
#   inflating: training/p016173.psv
#   inflating: training/p016174.psv
#   inflating: training/p016175.psv
#   inflating: training/p016176.psv
#   inflating: training/p016177.psv
#   inflating: training/p016178.psv
#   inflating: training/p016179.psv
#   inflating: training/p016180.psv
#   inflating: training/p016181.psv
#   inflating: training/p016182.psv
#   inflating: training/p016183.psv
#   inflating: training/p016184.psv
#   inflating: training/p016185.psv
#   inflating: training/p016186.psv
#   inflating: training/p016187.psv
#   inflating: training/p016188.psv
#   inflating: training/p016189.psv
#   inflating: training/p016190.psv
#   inflating: training/p016191.psv
#   inflating: training/p016192.psv
#   inflating: training/p016193.psv
#   inflating: training/p016194.psv
#   inflating: training/p016195.psv
#   inflating: training/p016196.psv
#   inflating: training/p016197.psv
#   inflating: training/p016198.psv
#   inflating: training/p016199.psv
#   inflating: training/p016200.psv
#   inflating: training/p016201.psv
#   inflating: training/p016202.psv
#   inflating: training/p016203.psv
#   inflating: training/p016204.psv
#   inflating: training/p016205.psv
#   inflating: training/p016206.psv
#   inflating: training/p016207.psv
#   inflating: training/p016208.psv
#   inflating: training/p016209.psv
#   inflating: training/p016210.psv
#   inflating: training/p016211.psv
#   inflating: training/p016212.psv
#   inflating: training/p016213.psv
#   inflating: training/p016214.psv
#   inflating: training/p016215.psv
#   inflating: training/p016216.psv
#   inflating: training/p016217.psv
#   inflating: training/p016218.psv
#   inflating: training/p016219.psv
#   inflating: training/p016220.psv
#   inflating: training/p016221.psv
#   inflating: training/p016222.psv
#   inflating: training/p016223.psv
#   inflating: training/p016224.psv
#   inflating: training/p016225.psv
#   inflating: training/p016226.psv
#   inflating: training/p016227.psv
#   inflating: training/p016228.psv
#   inflating: training/p016229.psv
#   inflating: training/p016230.psv
#   inflating: training/p016231.psv
#   inflating: training/p016232.psv
#   inflating: training/p016233.psv
#   inflating: training/p016234.psv
#   inflating: training/p016235.psv
#   inflating: training/p016236.psv
#   inflating: training/p016237.psv
#   inflating: training/p016238.psv
#   inflating: training/p016239.psv
#   inflating: training/p016240.psv
#   inflating: training/p016241.psv
#   inflating: training/p016242.psv
#   inflating: training/p016243.psv
#   inflating: training/p016244.psv
#   inflating: training/p016245.psv
#   inflating: training/p016246.psv
#   inflating: training/p016247.psv
#   inflating: training/p016248.psv
#   inflating: training/p016249.psv
#   inflating: training/p016250.psv
#   inflating: training/p016251.psv
#   inflating: training/p016252.psv
#   inflating: training/p016253.psv
#   inflating: training/p016254.psv
#   inflating: training/p016255.psv
#   inflating: training/p016256.psv
#   inflating: training/p016257.psv
#   inflating: training/p016258.psv
#   inflating: training/p016259.psv
#   inflating: training/p016260.psv
#   inflating: training/p016261.psv
#   inflating: training/p016262.psv
#   inflating: training/p016263.psv
#   inflating: training/p016264.psv
#   inflating: training/p016265.psv
#   inflating: training/p016266.psv
#   inflating: training/p016267.psv
#   inflating: training/p016268.psv
#   inflating: training/p016269.psv
#   inflating: training/p016270.psv
#   inflating: training/p016271.psv
#   inflating: training/p016272.psv
#   inflating: training/p016273.psv
#   inflating: training/p016274.psv
#   inflating: training/p016275.psv
#   inflating: training/p016276.psv
#   inflating: training/p016277.psv
#   inflating: training/p016278.psv
#   inflating: training/p016279.psv
#   inflating: training/p016280.psv
#   inflating: training/p016281.psv
#   inflating: training/p016282.psv
#   inflating: training/p016283.psv
#   inflating: training/p016284.psv
#   inflating: training/p016285.psv
#   inflating: training/p016286.psv
#   inflating: training/p016287.psv
#   inflating: training/p016288.psv
#   inflating: training/p016289.psv
#   inflating: training/p016290.psv
#   inflating: training/p016291.psv
#   inflating: training/p016292.psv
#   inflating: training/p016293.psv
#   inflating: training/p016294.psv
#   inflating: training/p016295.psv
#   inflating: training/p016296.psv
#   inflating: training/p016297.psv
#   inflating: training/p016298.psv
#   inflating: training/p016299.psv
#   inflating: training/p016300.psv
#   inflating: training/p016301.psv
#   inflating: training/p016302.psv
#   inflating: training/p016303.psv
#   inflating: training/p016304.psv
#   inflating: training/p016305.psv
#   inflating: training/p016306.psv
#   inflating: training/p016307.psv
#   inflating: training/p016308.psv
#   inflating: training/p016309.psv
#   inflating: training/p016310.psv
#   inflating: training/p016311.psv
#   inflating: training/p016312.psv
#   inflating: training/p016313.psv
#   inflating: training/p016314.psv
#   inflating: training/p016315.psv
#   inflating: training/p016316.psv
#   inflating: training/p016317.psv
#   inflating: training/p016318.psv
#   inflating: training/p016319.psv
#   inflating: training/p016320.psv
#   inflating: training/p016321.psv
#   inflating: training/p016322.psv
#   inflating: training/p016323.psv
#   inflating: training/p016324.psv
#   inflating: training/p016325.psv
#   inflating: training/p016326.psv
#   inflating: training/p016327.psv
#   inflating: training/p016328.psv
#   inflating: training/p016329.psv
#   inflating: training/p016330.psv
#   inflating: training/p016331.psv
#   inflating: training/p016332.psv
#   inflating: training/p016333.psv
#   inflating: training/p016334.psv
#   inflating: training/p016335.psv
#   inflating: training/p016336.psv
#   inflating: training/p016337.psv
#   inflating: training/p016338.psv
#   inflating: training/p016339.psv
#   inflating: training/p016340.psv
#   inflating: training/p016341.psv
#   inflating: training/p016342.psv
#   inflating: training/p016343.psv
#   inflating: training/p016344.psv
#   inflating: training/p016345.psv
#   inflating: training/p016346.psv
#   inflating: training/p016347.psv
#   inflating: training/p016348.psv
#   inflating: training/p016349.psv
#   inflating: training/p016350.psv
#   inflating: training/p016351.psv
#   inflating: training/p016352.psv
#   inflating: training/p016353.psv
#   inflating: training/p016354.psv
#   inflating: training/p016355.psv
#   inflating: training/p016356.psv
#   inflating: training/p016357.psv
#   inflating: training/p016358.psv
#   inflating: training/p016359.psv
#   inflating: training/p016360.psv
#   inflating: training/p016361.psv
#   inflating: training/p016362.psv
#   inflating: training/p016363.psv
#   inflating: training/p016364.psv
#   inflating: training/p016365.psv
#   inflating: training/p016366.psv
#   inflating: training/p016367.psv
#   inflating: training/p016368.psv
#   inflating: training/p016369.psv
#   inflating: training/p016370.psv
#   inflating: training/p016371.psv
#   inflating: training/p016372.psv
#   inflating: training/p016373.psv
#   inflating: training/p016374.psv
#   inflating: training/p016375.psv
#   inflating: training/p016376.psv
#   inflating: training/p016377.psv
#   inflating: training/p016378.psv
#   inflating: training/p016379.psv
#   inflating: training/p016380.psv
#   inflating: training/p016381.psv
#   inflating: training/p016382.psv
#   inflating: training/p016383.psv
#   inflating: training/p016384.psv
#   inflating: training/p016385.psv
#   inflating: training/p016386.psv
#   inflating: training/p016387.psv
#   inflating: training/p016388.psv
#   inflating: training/p016389.psv
#   inflating: training/p016390.psv
#   inflating: training/p016391.psv
#   inflating: training/p016392.psv
#   inflating: training/p016393.psv
#   inflating: training/p016394.psv
#   inflating: training/p016395.psv
#   inflating: training/p016396.psv
#   inflating: training/p016397.psv
#   inflating: training/p016398.psv
#   inflating: training/p016399.psv
#   inflating: training/p016400.psv
#   inflating: training/p016401.psv
#   inflating: training/p016402.psv
#   inflating: training/p016403.psv
#   inflating: training/p016404.psv
#   inflating: training/p016405.psv
#   inflating: training/p016406.psv
#   inflating: training/p016407.psv
#   inflating: training/p016408.psv
#   inflating: training/p016409.psv
#   inflating: training/p016410.psv
#   inflating: training/p016411.psv
#   inflating: training/p016412.psv
#   inflating: training/p016413.psv
#   inflating: training/p016414.psv
#   inflating: training/p016415.psv
#   inflating: training/p016416.psv
#   inflating: training/p016417.psv
#   inflating: training/p016418.psv
#   inflating: training/p016419.psv
#   inflating: training/p016420.psv
#   inflating: training/p016421.psv
#   inflating: training/p016422.psv
#   inflating: training/p016423.psv
#   inflating: training/p016424.psv
#   inflating: training/p016425.psv
#   inflating: training/p016426.psv
#   inflating: training/p016427.psv
#   inflating: training/p016428.psv
#   inflating: training/p016429.psv
#   inflating: training/p016430.psv
#   inflating: training/p016431.psv
#   inflating: training/p016432.psv
#   inflating: training/p016433.psv
#   inflating: training/p016434.psv
#   inflating: training/p016435.psv
#   inflating: training/p016436.psv
#   inflating: training/p016437.psv
#   inflating: training/p016438.psv
#   inflating: training/p016439.psv
#   inflating: training/p016440.psv
#   inflating: training/p016441.psv
#   inflating: training/p016442.psv
#   inflating: training/p016443.psv
#   inflating: training/p016444.psv
#   inflating: training/p016445.psv
#   inflating: training/p016446.psv
#   inflating: training/p016447.psv
#   inflating: training/p016448.psv
#   inflating: training/p016449.psv
#   inflating: training/p016450.psv
#   inflating: training/p016451.psv
#   inflating: training/p016452.psv
#   inflating: training/p016453.psv
#   inflating: training/p016454.psv
#   inflating: training/p016455.psv
#   inflating: training/p016456.psv
#   inflating: training/p016457.psv
#   inflating: training/p016458.psv
#   inflating: training/p016459.psv
#   inflating: training/p016460.psv
#   inflating: training/p016461.psv
#   inflating: training/p016462.psv
#   inflating: training/p016463.psv
#   inflating: training/p016464.psv
#   inflating: training/p016465.psv
#   inflating: training/p016466.psv
#   inflating: training/p016467.psv
#   inflating: training/p016468.psv
#   inflating: training/p016469.psv
#   inflating: training/p016470.psv
#   inflating: training/p016471.psv
#   inflating: training/p016472.psv
#   inflating: training/p016473.psv
#   inflating: training/p016474.psv
#   inflating: training/p016475.psv
#   inflating: training/p016476.psv
#   inflating: training/p016477.psv
#   inflating: training/p016478.psv
#   inflating: training/p016479.psv
#   inflating: training/p016480.psv
#   inflating: training/p016481.psv
#   inflating: training/p016482.psv
#   inflating: training/p016483.psv
#   inflating: training/p016484.psv
#   inflating: training/p016485.psv
#   inflating: training/p016486.psv
#   inflating: training/p016487.psv
#   inflating: training/p016488.psv
#   inflating: training/p016489.psv
#   inflating: training/p016490.psv
#   inflating: training/p016491.psv
#   inflating: training/p016492.psv
#   inflating: training/p016493.psv
#   inflating: training/p016494.psv
#   inflating: training/p016495.psv
#   inflating: training/p016496.psv
#   inflating: training/p016497.psv
#   inflating: training/p016498.psv
#   inflating: training/p016499.psv
#   inflating: training/p016500.psv
#   inflating: training/p016501.psv
#   inflating: training/p016502.psv
#   inflating: training/p016503.psv
#   inflating: training/p016504.psv
#   inflating: training/p016505.psv
#   inflating: training/p016506.psv
#   inflating: training/p016507.psv
#   inflating: training/p016508.psv
#   inflating: training/p016509.psv
#   inflating: training/p016510.psv
#   inflating: training/p016511.psv
#   inflating: training/p016512.psv
#   inflating: training/p016513.psv
#   inflating: training/p016514.psv
#   inflating: training/p016515.psv
#   inflating: training/p016516.psv
#   inflating: training/p016517.psv
#   inflating: training/p016518.psv
#   inflating: training/p016519.psv
#   inflating: training/p016520.psv
#   inflating: training/p016521.psv
#   inflating: training/p016522.psv
#   inflating: training/p016523.psv
#   inflating: training/p016524.psv
#   inflating: training/p016525.psv
#   inflating: training/p016526.psv
#   inflating: training/p016527.psv
#   inflating: training/p016528.psv
#   inflating: training/p016529.psv
#   inflating: training/p016530.psv
#   inflating: training/p016531.psv
#   inflating: training/p016532.psv
#   inflating: training/p016533.psv
#   inflating: training/p016534.psv
#   inflating: training/p016535.psv
#   inflating: training/p016536.psv
#   inflating: training/p016537.psv
#   inflating: training/p016538.psv
#   inflating: training/p016539.psv
#   inflating: training/p016540.psv
#   inflating: training/p016541.psv
#   inflating: training/p016542.psv
#   inflating: training/p016543.psv
#   inflating: training/p016544.psv
#   inflating: training/p016545.psv
#   inflating: training/p016546.psv
#   inflating: training/p016547.psv
#   inflating: training/p016548.psv
#   inflating: training/p016549.psv
#   inflating: training/p016550.psv
#   inflating: training/p016551.psv
#   inflating: training/p016552.psv
#   inflating: training/p016553.psv
#   inflating: training/p016554.psv
#   inflating: training/p016555.psv
#   inflating: training/p016556.psv
#   inflating: training/p016557.psv
#   inflating: training/p016558.psv
#   inflating: training/p016559.psv
#   inflating: training/p016560.psv
#   inflating: training/p016561.psv
#   inflating: training/p016562.psv
#   inflating: training/p016563.psv
#   inflating: training/p016564.psv
#   inflating: training/p016565.psv
#   inflating: training/p016566.psv
#   inflating: training/p016567.psv
#   inflating: training/p016568.psv
#   inflating: training/p016569.psv
#   inflating: training/p016570.psv
#   inflating: training/p016571.psv
#   inflating: training/p016572.psv
#   inflating: training/p016573.psv
#   inflating: training/p016574.psv
#   inflating: training/p016575.psv
#   inflating: training/p016576.psv
#   inflating: training/p016577.psv
#   inflating: training/p016578.psv
#   inflating: training/p016579.psv
#   inflating: training/p016580.psv
#   inflating: training/p016581.psv
#   inflating: training/p016582.psv
#   inflating: training/p016583.psv
#   inflating: training/p016584.psv
#   inflating: training/p016585.psv
#   inflating: training/p016586.psv
#   inflating: training/p016587.psv
#   inflating: training/p016588.psv
#   inflating: training/p016589.psv
#   inflating: training/p016590.psv
#   inflating: training/p016591.psv
#   inflating: training/p016592.psv
#   inflating: training/p016593.psv
#   inflating: training/p016594.psv
#   inflating: training/p016595.psv
#   inflating: training/p016596.psv
#   inflating: training/p016597.psv
# ...
#   inflating: training/p019917.psv
#   inflating: training/p019918.psv
#   inflating: training/p019919.psv
#   inflating: training/p019920.psv
#   inflating: training/p019921.psv
#   inflating: training/p019922.psv
#   inflating: training/p019923.psv
#   inflating: training/p019924.psv
#   inflating: training/p019925.psv
#   inflating: training/p019926.psv
#   inflating: training/p019927.psv
#   inflating: training/p019928.psv
#   inflating: training/p019929.psv
#   inflating: training/p019930.psv
#   inflating: training/p019931.psv
#   inflating: training/p019932.psv
#   inflating: training/p019933.psv
#   inflating: training/p019934.psv
#   inflating: training/p019935.psv
#   inflating: training/p019936.psv
#   inflating: training/p019937.psv
#   inflating: training/p019938.psv
#   inflating: training/p019939.psv
#   inflating: training/p019940.psv
#   inflating: training/p019941.psv
#   inflating: training/p019942.psv
#   inflating: training/p019943.psv
#   inflating: training/p019944.psv
#   inflating: training/p019945.psv
#   inflating: training/p019946.psv
#   inflating: training/p019947.psv
#   inflating: training/p019948.psv
#   inflating: training/p019949.psv
#   inflating: training/p019950.psv
#   inflating: training/p019951.psv
#   inflating: training/p019952.psv
#   inflating: training/p019953.psv
#   inflating: training/p019954.psv
#   inflating: training/p019955.psv
#   inflating: training/p019956.psv
#   inflating: training/p019957.psv
#   inflating: training/p019958.psv
#   inflating: training/p019959.psv
#   inflating: training/p019960.psv
#   inflating: training/p019961.psv
#   inflating: training/p019962.psv
#   inflating: training/p019963.psv
#   inflating: training/p019964.psv
#   inflating: training/p019965.psv
#   inflating: training/p019966.psv
#   inflating: training/p019967.psv
#   inflating: training/p019968.psv
#   inflating: training/p019969.psv
#   inflating: training/p019970.psv
#   inflating: training/p019971.psv
#   inflating: training/p019972.psv
#   inflating: training/p019973.psv
#   inflating: training/p019974.psv
#   inflating: training/p019975.psv
#   inflating: training/p019976.psv
#   inflating: training/p019977.psv
#   inflating: training/p019978.psv
#   inflating: training/p019979.psv
#   inflating: training/p019980.psv
#   inflating: training/p019981.psv
#   inflating: training/p019982.psv
#   inflating: training/p019983.psv
#   inflating: training/p019984.psv
#   inflating: training/p019985.psv
#   inflating: training/p019986.psv
#   inflating: training/p019987.psv
#   inflating: training/p019988.psv
#   inflating: training/p019989.psv
#   inflating: training/p019990.psv
#   inflating: training/p019991.psv
#   inflating: training/p019992.psv
#   inflating: training/p019993.psv
#   inflating: training/p019994.psv
#   inflating: training/p019995.psv
#   inflating: training/p019996.psv
#   inflating: training/p019997.psv
#   inflating: training/p019998.psv
#   inflating: training/p019999.psv
#   inflating: training/p020000.psv
#   inflating: training/p020007.psv
#   inflating: training/p020308.psv
#   inflating: training/p020309.psv
#   inflating: training/p020310.psv
#   inflating: training/p020311.psv
#   inflating: training/p020312.psv
#   inflating: training/p020313.psv
#   inflating: training/p020314.psv
#   inflating: training/p020315.psv
#   inflating: training/p020316.psv
#   inflating: training/p020317.psv
#   inflating: training/p020318.psv
#   inflating: training/p020319.psv
#   inflating: training/p020320.psv
#   inflating: training/p020321.psv
#   inflating: training/p020322.psv
#   inflating: training/p020323.psv
#   inflating: training/p020324.psv
#   inflating: training/p020325.psv
#   inflating: training/p020326.psv
#   inflating: training/p020327.psv
#   inflating: training/p020328.psv
#   inflating: training/p020329.psv
#   inflating: training/p020330.psv
#   inflating: training/p020331.psv
#   inflating: training/p020332.psv
#   inflating: training/p020333.psv
#   inflating: training/p020334.psv
#   inflating: training/p020335.psv
#   inflating: training/p020336.psv
#   inflating: training/p020337.psv
#   inflating: training/p020338.psv
#   inflating: training/p020339.psv
#   inflating: training/p020340.psv
#   inflating: training/p020341.psv
#   inflating: training/p020342.psv
#   inflating: training/p020343.psv
#   inflating: training/p020344.psv
#   inflating: training/p020345.psv
#   inflating: training/p020346.psv
#   inflating: training/p020347.psv
#   inflating: training/p020348.psv
#   inflating: training/p020349.psv
#   inflating: training/p020350.psv
#   inflating: training/p020351.psv
#   inflating: training/p020352.psv
#   inflating: training/p020353.psv
#   inflating: training/p020354.psv
#   inflating: training/p020355.psv
#   inflating: training/p020356.psv
#   inflating: training/p020357.psv
#   inflating: training/p020358.psv
#   inflating: training/p020359.psv
#   inflating: training/p020360.psv
#   inflating: training/p020361.psv
#   inflating: training/p020362.psv
#   inflating: training/p020363.psv
#   inflating: training/p020364.psv
#   inflating: training/p020365.psv
#   inflating: training/p020366.psv
#   inflating: training/p020367.psv
#   inflating: training/p020368.psv
#   inflating: training/p020369.psv
#   inflating: training/p020370.psv
#   inflating: training/p020371.psv
#   inflating: training/p020372.psv
#   inflating: training/p020373.psv
#   inflating: training/p020374.psv
#   inflating: training/p020375.psv
#   inflating: training/p020376.psv
#   inflating: training/p020377.psv
#   inflating: training/p020378.psv
#   inflating: training/p020379.psv
#   inflating: training/p020380.psv
#   inflating: training/p020381.psv
#   inflating: training/p020382.psv
#   inflating: training/p020383.psv
#   inflating: training/p020384.psv
#   inflating: training/p020385.psv
#   inflating: training/p020386.psv
#   inflating: training/p020387.psv
#   inflating: training/p020388.psv
#   inflating: training/p020389.psv
#   inflating: training/p020390.psv
#   inflating: training/p020391.psv
#   inflating: training/p020392.psv
#   inflating: training/p020393.psv
#   inflating: training/p020394.psv
#   inflating: training/p020395.psv
#   inflating: training/p020396.psv
#   inflating: training/p020397.psv
#   inflating: training/p020398.psv
#   inflating: training/p020399.psv
#   inflating: training/p020400.psv
#   inflating: training/p020401.psv
#   inflating: training/p020402.psv
#   inflating: training/p020403.psv
#   inflating: training/p020404.psv
#   inflating: training/p020405.psv
#   inflating: training/p020406.psv
#   inflating: training/p020407.psv
#   inflating: training/p020408.psv
#   inflating: training/p020409.psv
#   inflating: training/p020410.psv
#   inflating: training/p020411.psv
#   inflating: training/p020412.psv
#   inflating: training/p020413.psv
#   inflating: training/p020414.psv
#   inflating: training/p020415.psv
#   inflating: training/p020416.psv
#   inflating: training/p020417.psv
#   inflating: training/p020418.psv
#   inflating: training/p020419.psv
#   inflating: training/p020420.psv
#   inflating: training/p020421.psv
#   inflating: training/p020422.psv
#   inflating: training/p020423.psv
#   inflating: training/p020424.psv
#   inflating: training/p020425.psv
#   inflating: training/p020426.psv
#   inflating: training/p020427.psv
#   inflating: training/p020428.psv
#   inflating: training/p020429.psv
#   inflating: training/p020430.psv
#   inflating: training/p020431.psv
#   inflating: training/p020432.psv
#   inflating: training/p020433.psv
#   inflating: training/p020434.psv
#   inflating: training/p020435.psv
#   inflating: training/p020436.psv
#   inflating: training/p020437.psv
#   inflating: training/p020438.psv
#   inflating: training/p020439.psv
#   inflating: training/p020440.psv
#   inflating: training/p020441.psv
#   inflating: training/p020442.psv
#   inflating: training/p020443.psv
#   inflating: training/p020444.psv
#   inflating: training/p020445.psv
#   inflating: training/p020446.psv
#   inflating: training/p020447.psv
#   inflating: training/p020448.psv
#   inflating: training/p020449.psv
#   inflating: training/p020450.psv
#   inflating: training/p020451.psv
#   inflating: training/p020452.psv
#   inflating: training/p020453.psv
#   inflating: training/p020454.psv
#   inflating: training/p020455.psv
#   inflating: training/p020456.psv
#   inflating: training/p020457.psv
#   inflating: training/p020458.psv
#   inflating: training/p020459.psv
#   inflating: training/p020460.psv
#   inflating: training/p020461.psv
#   inflating: training/p020462.psv
#   inflating: training/p020463.psv
#   inflating: training/p020464.psv
#   inflating: training/p020465.psv
#   inflating: training/p020466.psv
#   inflating: training/p020467.psv
#   inflating: training/p020468.psv
#   inflating: training/p020469.psv
#   inflating: training/p020470.psv
#   inflating: training/p020471.psv
#   inflating: training/p020472.psv
#   inflating: training/p020473.psv
#   inflating: training/p020474.psv
#   inflating: training/p020475.psv
#   inflating: training/p020476.psv
#   inflating: training/p020477.psv
#   inflating: training/p020478.psv
#   inflating: training/p020479.psv
#   inflating: training/p020480.psv
#   inflating: training/p020481.psv
#   inflating: training/p020482.psv
#   inflating: training/p020483.psv
#   inflating: training/p020484.psv
#   inflating: training/p020485.psv
#   inflating: training/p020486.psv
#   inflating: training/p020487.psv
#   inflating: training/p020488.psv
#   inflating: training/p020489.psv
#   inflating: training/p020490.psv
#   inflating: training/p020491.psv
#   inflating: training/p020492.psv
#   inflating: training/p020493.psv
#   inflating: training/p020494.psv
#   inflating: training/p020495.psv
#   inflating: training/p020496.psv
#   inflating: training/p020497.psv
#   inflating: training/p020498.psv
#   inflating: training/p020499.psv
#   inflating: training/p020500.psv
#   inflating: training/p020501.psv
#   inflating: training/p020502.psv
#   inflating: training/p020503.psv
#   inflating: training/p020504.psv
#   inflating: training/p020505.psv
#   inflating: training/p020506.psv
#   inflating: training/p020507.psv
#   inflating: training/p020508.psv
#   inflating: training/p020509.psv
#   inflating: training/p020510.psv
#   inflating: training/p020511.psv
#   inflating: training/p020512.psv
#   inflating: training/p020513.psv
#   inflating: training/p020514.psv
#   inflating: training/p020515.psv
#   inflating: training/p020516.psv
#   inflating: training/p020517.psv
#   inflating: training/p020518.psv
#   inflating: training/p020519.psv
#   inflating: training/p020520.psv
#   inflating: training/p020521.psv
#   inflating: training/p020522.psv
#   inflating: training/p020523.psv
#   inflating: training/p020524.psv
#   inflating: training/p020525.psv
#   inflating: training/p020526.psv
#   inflating: training/p020527.psv
#   inflating: training/p020528.psv
#   inflating: training/p020529.psv
#   inflating: training/p020530.psv
#   inflating: training/p020531.psv
#   inflating: training/p020532.psv
#   inflating: training/p020533.psv
#   inflating: training/p020534.psv
#   inflating: training/p020535.psv
#   inflating: training/p020536.psv
#   inflating: training/p020537.psv
#   inflating: training/p020538.psv
#   inflating: training/p020539.psv
#   inflating: training/p020540.psv
#   inflating: training/p020541.psv
#   inflating: training/p020542.psv
#   inflating: training/p020543.psv
#   inflating: training/p020544.psv
#   inflating: training/p020545.psv
#   inflating: training/p020546.psv
#   inflating: training/p020547.psv
#   inflating: training/p020548.psv
#   inflating: training/p020549.psv
#   inflating: training/p020550.psv
#   inflating: training/p020551.psv
#   inflating: training/p020552.psv
#   inflating: training/p020553.psv
#   inflating: training/p020554.psv
#   inflating: training/p020555.psv
#   inflating: training/p020556.psv
#   inflating: training/p020557.psv
#   inflating: training/p020558.psv
#   inflating: training/p020559.psv
#   inflating: training/p020560.psv
#   inflating: training/p020561.psv
#   inflating: training/p020562.psv
#   inflating: training/p020563.psv
#   inflating: training/p020564.psv
#   inflating: training/p020565.psv
#   inflating: training/p020566.psv
#   inflating: training/p020567.psv
#   inflating: training/p020568.psv
#   inflating: training/p020569.psv
#   inflating: training/p020570.psv
#   inflating: training/p020571.psv
#   inflating: training/p020572.psv
#   inflating: training/p020573.psv
#   inflating: training/p020574.psv
#   inflating: training/p020575.psv
#   inflating: training/p020576.psv
#   inflating: training/p020577.psv
#   inflating: training/p020578.psv
#   inflating: training/p020579.psv
#   inflating: training/p020580.psv
#   inflating: training/p020581.psv
#   inflating: training/p020582.psv
#   inflating: training/p020583.psv
#   inflating: training/p020584.psv
#   inflating: training/p020585.psv
#   inflating: training/p020586.psv
#   inflating: training/p020587.psv
#   inflating: training/p020588.psv
#   inflating: training/p020589.psv
#   inflating: training/p020590.psv
#   inflating: training/p020591.psv
#   inflating: training/p020592.psv
#   inflating: training/p020593.psv
#   inflating: training/p020594.psv
#   inflating: training/p020595.psv
#   inflating: training/p020596.psv
#   inflating: training/p020597.psv
#   inflating: training/p020598.psv
#   inflating: training/p020599.psv
#   inflating: training/p020600.psv
#   inflating: training/p020601.psv
#   inflating: training/p020602.psv
#   inflating: training/p020603.psv
#   inflating: training/p020604.psv
#   inflating: training/p020605.psv
#   inflating: training/p020606.psv
#   inflating: training/p020607.psv
#   inflating: training/p020608.psv
#   inflating: training/p020609.psv
#   inflating: training/p020610.psv
#   inflating: training/p020611.psv
#   inflating: training/p020612.psv
#   inflating: training/p020613.psv
#   inflating: training/p020614.psv
#   inflating: training/p020615.psv
#   inflating: training/p020616.psv
#   inflating: training/p020617.psv
#   inflating: training/p020618.psv
#   inflating: training/p020619.psv
#   inflating: training/p020620.psv
#   inflating: training/p020621.psv
#   inflating: training/p020622.psv
#   inflating: training/p020623.psv
#   inflating: training/p020624.psv
#   inflating: training/p020625.psv
#   inflating: training/p020626.psv
#   inflating: training/p020627.psv
#   inflating: training/p020628.psv
#   inflating: training/p020629.psv
#   inflating: training/p020630.psv
#   inflating: training/p020631.psv
#   inflating: training/p020632.psv
#   inflating: training/p020633.psv
#   inflating: training/p020634.psv
#   inflating: training/p020635.psv
#   inflating: training/p020636.psv
#   inflating: training/p020637.psv
#   inflating: training/p020638.psv
#   inflating: training/p020639.psv
#   inflating: training/p020640.psv
#   inflating: training/p020641.psv
#   inflating: training/p020642.psv
#   inflating: training/p020643.psv

# %%
def load_single_file(file_path):
    df = pd.read_csv(file_path, sep="|")
    df['PatientID'] = file_path.split(os.sep)[-1][:-4]
    df['Hour'] = df.index
    keep_cols = ['PatientID', 'Age', 'Gender', 'SepsisLabel', 'Hour',
                 'HR', 'O2Sat', 'SBP', 'DBP', 'Resp']
    df = df[keep_cols]
    df.rename(columns={'Gender': 'Sex', 'SepsisLabel': 'HasSepsis'}, inplace=True)
    return df

def create_final_table():
    final_df = pd.DataFrame()
    patient_list = range(1, 11)
    patient_list = [f'p{str(s).zfill(6)}.psv' for s in patient_list]
    for f in patient_list:
        df = load_single_file(os.path.join("training", f))
        final_df = pd.concat([final_df, df])
    final_df.to_csv('sepsis.csv',index=False)
create_final_table()

# %%
# Load the PPG data
user = '100004'
signals, fields = wfdb.rdsamp(f'{user}_PPG', pn_dir=f'butppg/{user}')
ppg = signals.flatten()
ppg = ppg[:200]
ppg -= ppg.mean()
fs = fields['fs']
ppg_time = np.arange(len(ppg))/fs

# Save it in a DataFrame
df = pd.DataFrame()
df['Time'] = ppg_time
df['PPG'] = ppg
df.to_csv('ppg.csv', index=False)

plt.figure()
plt.plot(df['Time'], df['PPG'])
plt.show()

# %% [markdown]
# # Instructions

# %% [markdown]
# To get full credit for this assignment, we should be able to run your entire notbook from start to finish without any errors. You can check this yourself by selecting "Runtime" > "Run all" in the Google Colab menu.

# %% [markdown]
# # Exercise 1: Working with PPG Data

# %% [markdown]
# This exercise will involve the same PPG we used in the last homework assignment.

# %%
df = pd.read_csv("ppg.csv")
df
# Out:
#          Time        PPG
# 0    0.000000  -5.088518
# 1    0.033333 -12.501646
# 2    0.066667 -16.617164
# 3    0.100000 -20.412686
# 4    0.133333 -16.688403
# ..        ...        ...
# 195  6.500000  30.430563
# 196  6.533333  21.500355
# 197  6.566667  21.367937
# 198  6.600000  20.677867
# 199  6.633333  19.552406
#
# [200 rows x 2 columns]

# %% [markdown]
# **(Part 1)** Write code that will calculate the sampling rate of this signal.

# %%
sr = int(1/(df['Time'][1]-df['Time'][0]))
sr
# Out:
# 30

# %% [markdown]
# **(Part 2)** If we were to analyze this data in the frequency domain, at which frequency range would we expect to see the most content? We are looking for a ballpark answer, but your answer should include a brief explanation.
#
# *Hint:* Think about translating "beats per minute" to "Hertz".

# %% [markdown]
# Typical heart rates are 60–100 bpm == 1–1.67 Hz, but heart rates can go even faster if someone is exercising.

# %% [markdown]
# **(Part 3)** To prepare this data so that we can generate FFTs and spectrograms, convert it into two `numpy` arrays:
# 1. A 1D array for the `'Time'` column
# 2. A 1D array for the `'PPG'` column minus the average value of that column so that the resulting array has an average of 0

# %%
time = df['Time'].values
ppg = df['PPG'].values

# %% [markdown]
# **(Part 4)** Plot the FFT of the PPG signal. The function that we created during class has been copied below for your convenience, but you will need to make sure that the inputs are correct and make the plot informative.

# %%
from numpy.fft import fftfreq
from scipy.fftpack import fft
def show_fft(x, y, fs=1000, time_ylim=None, fft_xlim_max=None):
    """
    Shows the time-domain signal and the corresponding FFT
    x: the timestamps of the signal as a Numpy array
    y: the values of the signal as a Numpy array
    fs: the sampling rate of our signal
    time_ylim: the boundaries of the y-axis for the time-domain plot
    fft_xlim_max: the right boundary for the x-axis of the FFT plot,
    indicating the highest frequency we care to view
    """
    # Compute the FFT
    fft_mag = np.abs(fft(y))
    freqs = fftfreq(len(y), 1/fs)

    # Keep the components associated with positive frequencies
    pos_freq_idxs = freqs >= 0
    freqs = freqs[pos_freq_idxs]
    fft_mag = fft_mag[pos_freq_idxs]

    # Show the signal in the time domain
    plt.figure(figsize=(12, 3))
    plt.subplot(1, 2, 1)
    plt.plot(x, y)
    plt.xlabel('Time (s)')
    plt.ylabel('X(time)')
    if time_ylim:
        plt.ylim(time_ylim[0], time_ylim[1])
    plt.title('Time Domain')

    # Show the signal in the frequency domain
    plt.subplot(1, 2, 2)
    plt.stem(freqs, fft_mag, markerfmt=" ", basefmt="-")
    plt.xlabel('Freq (Hz)')
    plt.ylabel('FFT Amplitude |X(freq)|')
    plt.xlim(-0.1, fft_xlim_max if fft_xlim_max else freqs.max())
    plt.title('Frequency Domain')
    plt.show()

# %%
show_fft(time, ppg, fs=sr, fft_xlim_max=None)

# %% [markdown]
# **(Part 5)** How does the FTT align or misalign with the expectations you laid out in Part 2?

# %% [markdown]
# The most prominent peak in the spectrogram is at roughly 0.75 Hz. That equates to approximately 45 bpm, which is lower than we would have expected. More generally, there are two "clumps" of frequency content. One is roughly centered around 1 Hz (60 bpm), which falls within the range that we specified earlier. The other cluster, which is less pronounced and looks like a harmonic of the first one, is roughly centered around 3 Hz (180 bpm). While that seems a bit fast, it turns out there are roughly 2.75 beats per second (165 bpm) in the first half of the signal, so perhaps this person has a very fast heartbeat.

# %% [markdown]
# **(Part 6)** Plot the spectrogram of the PPG signal. The function that we created during class has been copied below for your convenience, but you will need to make sure that the inputs are correct and make the plot informative.

# %%
from scipy import signal
def show_spectrogram(x, y, fs=1000, win_len=1, win_percent_overlap=12.5,
                     time_ylim=None, fft_xlim_max=None):
    """
    Shows the time-domain signal and the corresponding spectrogram
    x: the timestamps of the signal as a Numpy array
    y: the values of the signal as a Numpy array
    fs: the sampling rate of our signal
    win_len: the length of the window in seconds
    win_percent_overlap: the percentage of overlap between consecutive windows
    time_ylim: the boundaries of the y-axis for the time-domain plot
    fft_xlim_max: the top boundary for the y-axis of the spectrogram,
    indicating the highest frequency we care to view
    """
    # Compute the window parameters
    num_window_points_len = int(fs*win_len)
    num_window_points_overlap = int(num_window_points_len*(win_percent_overlap/100))

    # Compute the spectrogram
    freqs, times, spectro = signal.spectrogram(y, fs,
                                               nperseg=num_window_points_len,
                                               noverlap=num_window_points_overlap)

     # Show the signal in the time domain
    plt.figure(figsize=(12, 3))
    plt.subplot(1, 2, 1)
    plt.plot(x, y)
    plt.xlabel('Time (s)')
    plt.ylabel('X(time)')
    if time_ylim:
        plt.ylim(time_ylim[0], time_ylim[1])
    plt.title('Time Domain')

    # Show the signal in the frequency domain
    plt.subplot(1, 2, 2)
    plt.pcolormesh(times, freqs, spectro, shading='gouraud')
    plt.xlabel('Time (s)')
    plt.ylabel('Frequency (Hz)')
    plt.ylim(-0.1, fft_xlim_max if fft_xlim_max else freqs.max())
    plt.title('Frequency Domain')
    plt.show()

# %%
show_spectrogram(time, ppg, fs=fs, win_len=1, win_percent_overlap=75,
                 time_ylim=None, fft_xlim_max=None)

# %% [markdown]
# **(Part 7)** How does the spectrogram align or misalign with the expectations you laid out in Part 2?

# %% [markdown]
# In the first half of the signal, there is a faint horizontal line roughly around 2.75 Hz, which is where we saw one of the clumps in the FFT. Between 4 and 5 seconds, there is a more pronounced horizontal line around 1 Hz. This makes sense because the peak is much larger in the graph and there is roughly 1 peak per second. In fact, we if we look closer, we can actually see that there is also frequency content around 2.75 Hz in that chunk of time, although it is much less pronounced.

# %% [markdown]
# **(Part 8)** Apply a filter to emphasize the frequency content in the range you specified in **(Part 2)** and to deemphasize the noisy data at the end of the signal. This filter is not expected to completely eliminate the noise, but it should make the apparent heart rate of the patient more apparent. The functions that we created during class have been copied below for your convenience, but you do not need use both of them.
#
# Show your filtered signal with its FFT, similar to what you did for **(Part 4)**.

# %%
from scipy.signal import butter, filtfilt

def butter_lowpass(data, fs, cutoff, order=5):
    """
    Apply a low-pass filter to time-series data
    data: the values of the time-series data (not the timestamps)
    fs: the sampling rate
    cutoff: the cutoff frequency
    order: the order of the Butterworth filter
    """
    # Define the cutoff frequency in terms of the Nyquist frequency of the signal
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq

    # Compute the low-pass filter
    b, a = butter(order, normal_cutoff, btype='lowpass')

    # Apply the filter
    y = filtfilt(b, a, data)
    return y

# %%
from scipy.signal import butter, filtfilt

def butter_bandpass(data, fs, lower_cutoff, upper_cutoff, order=5):
    """
    Apply a band-pass filter to time-series data
    data: the values of the time-series data (not the timestamps)
    fs: the sampling rate
    lower_cutoff: the lower cutoff frequency
    upper_cutoff: the upper cutoff frequency
    order: the order of the Butterworth filter
    """
    # Define the cutoff frequency in terms of the Nyquist frequency of the signal
    nyq = 0.5 * fs
    normal_lower_cutoff = lower_cutoff / nyq
    normal_upper_cutoff = upper_cutoff / nyq

    # Compute the band-pass filter
    b, a = butter(order, [normal_lower_cutoff, normal_upper_cutoff], btype='bandpass')

    # Apply the filter
    y = filtfilt(b, a, data)
    return y

# %%
ppg_filt = butter_bandpass(ppg, fs=sr, lower_cutoff=1, upper_cutoff=3)
show_fft(time, ppg_filt, fs=sr, fft_xlim_max=None)

# %% [markdown]
# **(Part 9)** Write code that identifies the peak frequency in the FFT of your filtered signal. This value should represent the average heart rate of the person and therefore fall within the range you specified in **(Part 2)**.

# %%
# Compute the FFT
fft_mag = np.abs(fft(ppg_filt))
freqs = fftfreq(len(ppg_filt), 1/fs)

# Keep the components associated with positive frequencies
pos_freq_idxs = freqs >= 0
freqs = freqs[pos_freq_idxs]
fft_mag = fft_mag[pos_freq_idxs]

# Identify the peak
peak_ind = fft_mag.argmax()
peak_freq = freqs[peak_ind]
peak_freq
# Out:
# 2.6999999999999997
